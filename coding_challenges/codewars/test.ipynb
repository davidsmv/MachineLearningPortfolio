# %%
# list of words
s = ["tree", "car"]
print(len(min(s, key=len)))
# Out:
# 3

# %%
range
# Out:
# ['a', 'b']

# %%
i = []
d = []
if not i or not d:
    print("i is empty or d is None")
# Out:
# i is empty or d is None

# %%
def mul(nums):
    result = 1
    for n in nums:
        result *= n
    return result

print(mul([2, 2]))
# Out:
# 4
